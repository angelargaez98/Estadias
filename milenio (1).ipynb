# %%
import requests
milenio = requests.get("https://www.milenio.com/")
milenio
# Out:
# <Response [200]>

# %%
milenio.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(milenio.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script type="text/javascript">
#    dataLayer = [{
#       'varSeccion': '',
#       'varSubSeccion': '',
#       'varSubSubSeccion': '',
#       'varAutor': '',
#       'varPlaza': 'Nacional',
#       'varFormato': 'Portada',
#       'varEditor' : '',
#       'varFechaPublicacion' : ''
#     }];
#   </script>
#   <script type="text/javascript">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-WWZ9QB');
#   </script>
#   <script async="" src="/bundles/camusassets/js/prebid3.7.1.js" type="text/javascript">
#   </script>
#   <script async="" src="//cdn.tinypass.com/api/tinypass.min.js" type="text/javascript">
#   </script>
# ...

# %%
panel= soup.find(class_="media-container")
forecast = panel(class_="text ")##

# %%
forecast_items = (class_="title")##

# %%
tonight = forecast_items[0]

# %%
print(tonight.prettify())
# Out:
# <div class="title" data-camus-removable="Titulo">
#  <h2 data-camus-color="color" data-camus-title="" style="color: rgba(177,1,36,1)">
#   Pandemia por covid-19: últimas noticias
#  </h2>
# </div>

# %%
period_tags = panel.select(".title ")

# %%
periods = [pt.get_text() for pt in period_tags]

# %%
import pandas as pd
weather = pd.DataFrame({
    "noticias": periods,
    
})
weather
# Out:
#                                             noticias
# 0        \nPandemia por covid-19: últimas noticias\n
# 1  \n\nCoronavirus en México: noticias de hoy sob...
# 2  \n\nMuertes por coronavirus en NY superan cifr...
# 3  \n\nChina reporta nuevos casos de coronavirus;...
# 4  \n\nReportan 112 muertes y mil 562 nuevos caso...
# 5  \n\nMapa del coronavirus en México; 8 estados ...
# 6  \n\nCréditos solidarios a la palabra llegarán ...
# 7  \n\nIMSS usa plasma de pacientes recuperados e...
