# %%
import requests
milenio = requests.get("https://www.milenio.com/")
milenio
# Out:
# <Response [200]>

# %%
milenio.status_code
# Out:
# 200

# %%
milenio.content
# Out:
# b'<!DOCTYPE html>\n<html>\n  <head>\n            <script type="text/javascript">\n    dataLayer = [{\n      \'varSeccion\': \'\',\n      \'varSubSeccion\': \'\',\n      \'varSubSubSeccion\': \'\',\n      \'varAutor\': \'\',\n      \'varPlaza\': \'Nacional\',\n      \'varFormato\': \'Portada\',\n      \'varEditor\' : \'\',\n      \'varFechaPublicacion\' : \'\'\n    }];\n  </script>\n                <script type="text/javascript">\n          (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n          new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n          j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n          \'//www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n          })(window,document,\'script\',\'dataLayer\',\'GTM-WWZ9QB\');\n        </script>\n          \n    <script type="text/javascript" async src="/bundles/camusassets/js/prebid3.7.1.js"></script>\n    <script type="text/javas
# ...

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(milenio.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <script type="text/javascript">
#    dataLayer = [{
#       'varSeccion': '',
#       'varSubSeccion': '',
#       'varSubSubSeccion': '',
#       'varAutor': '',
#       'varPlaza': 'Nacional',
#       'varFormato': 'Portada',
#       'varEditor' : '',
#       'varFechaPublicacion' : ''
#     }];
#   </script>
#   <script type="text/javascript">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#           new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#           j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#           '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#           })(window,document,'script','dataLayer','GTM-WWZ9QB');
#   </script>
#   <script async="" src="/bundles/camusassets/js/prebid3.7.1.js" type="text/javascript">
#   </script>
#   <script async="" src="//cdn.tinypass.com/api/tinypass.min.js" type="text/javascript">
#   </script>
# ...

# %%
panel= soup.find(class_="contenedor-notas-block")

# %%
forecast_items = panel(class_="sli-base")##

# %%
tonight = forecast_items[0]

# %%
print(tonight.prettify())
# Out:
# <div class="sli-base" data-camus-module-type="sli" data-camus-toolbar-position="topleft">
#  <div class="media-container">
#   <div class="headline" data-camus-color="border-color" style="border-color: rgba(177,1,36,1)">
#    <div class="title" data-camus-removable="Titulo">
#     <h2 data-camus-color="color" data-camus-title="" style="color: rgba(177,1,36,1)">
#      Pandemia por covid-19: últimas noticias
#     </h2>
#    </div>
#    <div class="arrows">
#     <button class="left" type="button">
#      <span class="glyphicon glyphicon-chevron-left">
#      </span>
#     </button>
#     <button class="right" type="button">
#      <span class="glyphicon glyphicon-chevron-right">
#      </span>
#     </button>
#    </div>
#   </div>
#   <div class="firms" data-camus-modules="">
#    <div class="foot-text-note" data-camus-template="sn_base_foot_text" data-camus-type="sn_base">
#     <div class="image">
#      <a href="/estados/coronavirus-casos-mexico-mapa-7-mayo">
# ...

# %%
period_tags = panel.select(".sli-base ")

# %%
periods = [pt.get_text() for pt in period_tags]

# %%
periods
# Out:
# ['\n\n\n\nPandemia por covid-19: últimas noticias\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMapa del coronavirus en México; en 7 días, 719 defunciones y 8 mil 877 casos\n\n\n\nEstados\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nMuertes por coronavirus en México ascienden a 2,961; hay 29,616 casos\n\n\n\nPolítica\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nEn la Central de Abasto de CdMx, operativo especial por coronavirus: López-Gatell\n\n\n\nComunidad\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCréditos solidarios a la palabra alcanzan una dispersión de 2 mil 883 mdp\n\n\n\nNegocios\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLópez-Gatell: remdesivir, con resultados prometedores en ronavirus\n\n\n\nComunidad\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTemas de la conferencia de salud sobre el coronavirus en México del 7 de mayo\n\n\n\nPolítica\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nVerifican medidas preventivas ante coronavirus en la Central de Abasto\n\n\n\nGobierno\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nRespeto a la IP, pero toca al Estado buscar desarrollo
# ...

# %%
import pandas as pd
weather = pd.DataFrame({
    "noticias": periods,
    
})
weather
# Out:
#                                              noticias
# 0   \n\n\n\n\n\n\n\n\n\n\n\nMapa del coronavirus e...
# 1   \n\n\n\n\n\n\n\n\n\n\n\n\n\nEsto es lo que ha ...
# 2   \n\n\n\n\n\n\n\n\n\n\n\nEn Los Cabos ya hay pl...
# 3   \n\n\n\n\n\n\n\n\n\n\n\n\n\n"No porque no tien...
# 4   \n\n\n\n\n\n\n\n\n\n\n\nMira el último concier...
# 5   \n\n\n\n\n\n\n\n\n\n\n\n\nNUEVO LEÓN\n\n\n\nVa...
# 6   \n\n\n\n\n\n\n\n\n\n\n\nGrupo Hotelero Santa F...
# 7   \n\n\n\n\n\n\n\n\n\n\n\n\nFAMOSOS\n\n\n\nSebas...
# 8   \n\n\n\n\n\n\n\n\n\n\n\n\nEXTRA CANCHA\n\n\n\n...
# 9   \n\n\n\n\n\n\n\n\n\n\n\n\n\nRegina Blandón luc...
# 10  \n\n\n\n\n\n\n\n\n\n\n\n\n\nDefinidas las fech...
# 11  \n\n\n\n\n\n\n\n\n\n\n\n\n\nEl exjugador de At...
# 12  \n\n\n\n\n\n\n\n\n\n\n\n\n\nColección Milenio ...
