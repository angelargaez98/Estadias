# %%
import requests
nacion= requests.get("https://www.lanacion.com.py/")

# %%
nacion
# Out:
# <Response [200]>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(nacion.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="" lang="es">
#  <head>
#   <link href="/pb/resources/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8">
#    <meta content="width=device-width, initial-scale=1.0, user-scalable=yes, minimum-scale=0.5, maximum-scale=2.0" id="viewport" name="viewport"/>
#    <meta content="la nacion, diario popular, popular, coronavirus, covid19 la nacion py, diario nacion, diario, impreso, nacional, paraguay, noticias, tendencias, investigacion, politica, economia, judiciales, pais, deportes, especiales, negocios, tecnologia, set, ips, ande, paraguay hoy, ultimas, 24 horas, ultima hora, editorial, lanacionpy, diarios de paraguay" property="keywords"/>
# ...

# %%
 na = soup.find_all(class_="title")

# %%
periods = [pt.get_text() for pt in na]

# %%
tag.getText()
# Out:
# '  El rompecabezas de Varadero - PARTE II Raúl Acosta fue asesinado el 18 de diciembre del 2009. Golpearon y cercenaron su cuerpo a la costa del río Paraguay, en el barrio Varadero. Las primeras pistas condujeron a una pelea que tuvo el pescador con su esposa, pero la trama va más allá.  '

# %%
for tag in na:

    print(tag.getText())
# Out:
#  LA NACIÓN
#   Fase 2: Reunirse con la familia todavía no está permitido El viceministro de Atención Integral de la Salud, Juan Carlos Portillo, recordó que en esta fase 2 de la cuarentena inteligente que entra en vigencia el 25 de mayo las reuniones familiares todavía no estarán permitidas.
#   Tras 36 días de encierro, 49 personas dejan albergue de Hernandarias
#   Comerciantes de Pedro Juan Caballero empiezan a cerrar negocios
#   Industria de la confección exige transparencia al Gobierno
#   Asintomáticos se realizan pruebas de COVID-19 en Hospital de Barrio Obrero El puesto fijo para test de COVID-19 dirigido a personas asintomáticas que podrían ser portadoras del virus se instaló en el Hospital de Barrio Obrero de Asunción esta mañana.
# ...

# %%
import pandas as pd
nacion = pd.DataFrame({
    "noticias": na,
   
})
nacion
# Out:
#                                              noticias
# 0                            [ , [LA NACIÓN],  , [ ]]
# 1   [ , [ , [Fase 2: Reunirse con la familia todav...
# 2   [ , [ , [Tras 36 días de encierro, 49 personas...
# 3   [ , [ , [Comerciantes de Pedro Juan Caballero ...
# 4   [ , [ , [Industria de la confección exige tran...
# 5   [ , [ , [Asintomáticos se realizan pruebas de ...
# 6   [ , [ , [Paraguay se sitúa entre los 45 países...
# 7   [ , [ , [Confirman absolución de culpa y pena ...
# 8   [ , [ , [Vallemí: Fiscalía investiga daño ambi...
# 9   [ , [ , [Fase 2: Reunirse con la familia todav...
# 10  [ , [ , [Quíntuple homicidio: Juicio a Bruno M...
# 11  [ , [ , [Proveedor de Salud debía presentar mu...
# 12  [ , [ , [Vuelo humanitario: Unos 170 compatrio...
# 13  [ , [ , [Día Internacional del Té: una experie...
# 14  [ , [ , [Lanzaron boletín de alerta sobre ince...
# 15  [ , [ , [Juicio oral a Camilo Soares, en etapa...
# ...

# %%
nacion.to_csv('2-la_nacion.csv')
