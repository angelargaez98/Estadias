# %%
import requests
economista= requests.get("https://www.eleconomista.com.mx/")

# %%
economista
# Out:
# <Response [200]>

# %%
economista.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7 ]><html lang="" class="no-js lt-ie10 lt-ie9 lt-ie8 lt-ie7 ie6"> <![endif]-->\n<!--[if IE 7 ]><html \tlang="" class="no-js lt-ie10 lt-ie9 lt-ie8 ie7"> <![endif]-->\n<!--[if IE 8 ]><html \tlang="" class="no-js lt-ie10 lt-ie9 ie8"> <![endif]-->\n<!--[if IE 9 ]><html \tlang="" class="no-js lt-ie10 ie9"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--><html lang="" class="no-js"><!--<![endif]-->\n<head>\n\t<meta charset="utf-8" />\n\t<meta http-equiv="X-UA-Compatible" content="IE=edge" />\n    \t<meta name="viewport" content="width=device-width, minimum-scale=1.0, maximum-scale=1.0, user-scalable=no, initial-scale=1.0" />\n    \t<link rel="manifest" href="/manifest.json">\n\t<!--FAVICON-->\t\t\n\t<link rel="shortcut icon" href="/__export/1503529426000/sites/eleconomista/arte/imagenes-redes/favicon.ico" />\n\t<meta property="fb:pages" content="127336447321880" />\n\t<meta property="fb:app_id" content="803434093018930" />\n\t<title> El Economista | Periódico especializado en finanzas y mercados</title>\n\t\t<meta name="description" content="Últimas noticias sobre la economía de México y el mundo. Información financiera y noticias actuales de economía, negocios, política, tipo de cambio, tecnología y empresas." />\n\t\t<link rel="canonical" href="https://www.eleconomista.com.mx" />\n\t<meta name="og:title" content="El Economista | Periódico especializado en finanzas y mercados" />\n\t<meta name="og:description" content="Últimas noticias sobre la economía de México y el mundo. Información financiera y noticias actuales de economía, negocios, política, tipo de cambio, tecnología y empresas." />\n\t<meta name="og:type" content="website" />\n\t<meta name="og:url" content="https://www.eleconomista.com.mx" />\n\t<meta name="og:image" content="https://www.eleconomista.com.mx/__export/1485304638978/sites/eleconomista/arte/logo-header-sticky.svg" />\n\t<meta name="og:site_name" content="El Economista" />\n\t<meta property="og:locale" content="es_MX" />\n\t<meta name="twitter:card" content="summary_large_image" />\n\t<meta name="twitter:title" content="El Economista | Periódico especializado en finanzas y mercados" />\n\t<meta name="twitter:image" content="https://www.eleconomista.com.mx/__export/1485304638978/sites/eleconomista/arte/logo-header-sticky.svg" />\n\t<meta name="twitter:site" content="@eleconomista" />\n\t<meta name="twitter:creator" content="@eleconomista" />\n\t<meta name="twitter:description" content="summary" />\n\t<meta name="theme-color" content="#008bc4">\n\t<meta name="format-detection" content="telephone=yes" />\n\t<meta name="cXenseParse:pageclass" content="frontpage"/>\n\t<meta name="cXenseParse:recs:recommendable" content="false">\n\t\n\t\n<!-- FONTS -->\n\t<link href="https://fonts.googleapis.com/css?family=Ubuntu:300,300i,400,400i,500,500i,700,700i" rel="stylesheet">\n\t<link rel="stylesheet" type="text/css" href="/__export/1587159979332/system/modules/com.tfsla.diario.eleconomista/resources/generales.min.css" />\n\t<link rel="stylesheet" type="text/css" href="/__export/1587159994372/system/modules/com.tfsla.diario.eleconomista/resources/home.min.css" />\n\t\t\t<script type="text/javascript" src="//widget.playoncenter.com/newplayer/ifriendly/embed.min.js"></script>\t\t\t\n\t\t\t<link rel="stylesheet" type="text/css" href="/__export/1587160066114/system/modules/com.tfsla.diario.eleconomista/resources/responsive.min.css" />\n\t<!-- Cxense Start -->\n\t<script type="text/javascript">\n\t    var cX = window.cX = window.cX || {}; cX.callQueue = cX.callQueue || [];\n\t    cX.CCE = cX.CCE || {}; cX.CCE.callQueue = cX.CCE.callQueue || [];\n\t    cX.callQueue.push([\'setSiteId\', \'9222351058919302876\']);\n\t    cX.callQueue.push([\'cint\',\'216\']);\n\t    cX.callQueue.push([\'sync\', \'smart\']);\n\t    cX.CCE.callQueue.push([\'sendPageViewEvent\']);\n\t    (function(d,s,e,t){e=d.createElement(s);e.type=\'text/java\'+s;e.async=\'async\';e.src=\'https://cdn.cxense.com/cx.cce.js\';t=d.getElements ...

# %%
economista.get_text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-b63b62da1781> in <module>
# ----> 1 economista.get_text()
#
# AttributeError: 'Response' object has no attribute 'get_text'

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(economista.content, 'html.parser')

# %%
panel= soup.find(class_="pb clearfix")

# %%
fo = panel(class_="entry-title")

# %%
tonight = fo[0]

# %%
print(tonight.prettify())
# Out:
# <div class="entry-title">
#  Emergencia sanitaria
# </div>

# %%
period = soup.find_all(class_="entry-title")

# %%
print(period)
# Out:
# [<div class="entry-title">
# 					Emergencia sanitaria</div>, <span class="entry-title">Presión para reapertura</span>, <span class="entry-title">En el 2020 ventas del sector retrocederán 40%: INA</span>, <span class="entry-title">Se estima que la medida deje al erario 4,400 millones de pesos</span>, <span class="entry-title">Afirma el CEESP</span>, <span class="entry-title">Ante los efectos negativos por el Covid-19</span>, <p class="entry-title">Llegada de turistas toca mínimo histórico</p>, <p class="entry-title">En la Bolsa Mexicana de Valores</p>, <p class="entry-title">Tres posibles escenarios futuros</p>, <p class="entry-title">En otros países la Ley lo contempla</p>, <p class="entry-title">Información oficial</p>, <p class="entry-title">Información oficial</p>, <p class="entry-title">Información oficial</p>, <p class="entry-title">Información Oficial</p>, <p class="entry-title">#Esbuenosaber</p>, <p class="entry-title">Información oficial</p>, <p class="entry-title">Contenido comercial</p>, <p class="entry-title">Información oficial</p>, <p class="entry-title">Información oficial</p>]

# %%
period_tags = panel.select(".entry-title")

# %%
periods = [pt.get_text() for pt in period]

# %%
periods
# Out:
# ['\n\t\t\t\t\tEmergencia sanitaria',
#  'Presión para reapertura',
#  'En el 2020 ventas del sector retrocederán 40%: INA',
#  'Se estima que la medida deje al erario 4,400 millones de pesos',
#  'Afirma el CEESP',
#  'Ante los efectos negativos por el Covid-19',
#  'Llegada de turistas toca mínimo histórico',
#  'En la Bolsa Mexicana de Valores',
#  'Tres posibles escenarios futuros',
#  'En otros países la Ley lo contempla',
#  'Información oficial',
#  'Información oficial',
#  'Información oficial',
#  'Información Oficial',
#  '#Esbuenosaber',
#  'Información oficial',
#  'Contenido comercial',
#  'Información oficial',
#  'Información oficial']

# %%
import pandas as pd
weather = pd.DataFrame({
    "noticias": periods,
   
})
weather
# Out:
#                                              noticias
# 0                    \n\t\t\t\t\tEmergencia sanitaria
# 1                             Presión para reapertura
# 2   En el 2020 ventas del sector retrocederán 40%:...
# 3   Se estima que la medida deje al erario 4,400 m...
# 4                                     Afirma el CEESP
# 5          Ante los efectos negativos por el Covid-19
# 6           Llegada de turistas toca mínimo histórico
# 7                     En la Bolsa Mexicana de Valores
# 8                    Tres posibles escenarios futuros
# 9                 En otros países la Ley lo contempla
# 10                                Información oficial
# 11                                Información oficial
# 12                                Información oficial
# 13                                Información Oficial
# 14                                      #Esbuenosaber
# 15                                Información oficial
# 16                                Contenido comercial
# 17                                Información oficial
# 18                                Información oficial
